# %%
import datalad.api as dl
# Out:
# [WARNING] Failed to load entrypoint gooey from datalad.extensions: ImportError(cannot import name 'clone' from 'datalad_next.patches' (/Users/brunoleitao/anaconda3/lib/python3.11/site-packages/datalad_next/patches/__init__.py))

# %%
dl.create(path='datalad-test', force=True)
# Out:
# ---------------------------------------------------------------------------
# MissingExternalDependency                 Traceback (most recent call last)
# /Users/brunoleitao/Documents/GitHub/OpenNeuro-utils/scripts/datalad-scripts.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/brunoleitao/Documents/GitHub/OpenNeuro-utils/scripts/datalad-scripts.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> dl.create(path='datalad-test', force=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/datalad/interface/base.py:773, in eval_results.<locals>.eval_func(*args, **kwargs)
#     768         return results
#     770 lgr.log(2,
#     771         "Returning return_func from eval_func for %s",
#     772         wrapped_class)
# --> 773 return return_func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/datalad/interface/base.py:763, in eval_results.<locals>.eval_func.<locals>.return_func(*args_, **kwargs_)
#     753 results = _execute_command_(
# ...
